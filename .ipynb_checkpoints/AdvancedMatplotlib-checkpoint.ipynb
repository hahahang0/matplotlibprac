# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv('iris.csv')

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])
plt.xlabel("Sapel Length")
plt.ylabel("Petal Length")
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
iris['Species']= iris['Species'].replace({"Iris-setosa":0,'Iris-versicolor':1,'Iris-virginica':2})

# %%
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1      2            4.9           3.0            1.4           0.2        0
# 32    33            5.2           4.1            1.5           0.1        0
# 40    41            5.0           3.5            1.3           0.3        0
# 117  118            7.7           3.8            6.7           2.2        2
# 144  145            6.7           3.3            5.7           2.5        2

# %%
plt.figure(figsize=(15,7))

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=.3)
plt.xlabel("Sapel Length")
plt.ylabel("Petal Length")
plt.colorbar()

# %%
batters = pd.read_csv('batter.csv')
batters.head(5)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
batters.shape
# Out:
# (605, 4)

# %%
sample_df = batters.sample(25)

# %%
sample_df
# Out:
#                batter  runs        avg  strike_rate
# 201          R Dhawan   190  21.111111   107.954545
# 299         CJ Jordan    75   9.375000   110.294118
# 512   Simarjeet Singh     7   7.000000    87.500000
# 47         MEK Hussey  1977  38.764706   119.963592
# 440      JR Hazlewood    18        NaN    66.666667
# 587        Yash Dayal     0   0.000000     0.000000
# 118         RS Bopara   531  29.500000   113.461538
# 100         V Shankar   731  23.580645   118.668831
# 597         IC Pandey     0   0.000000     0.000000
# 244          M Morkel   126  11.454545   135.483871
# 127          MR Marsh   476  22.666667   120.812183
# 123   Gurkeerat Singh   511  21.291667   117.201835
# 297           B Akhil    76  12.666667   133.333333
# 183         JM Sharma   234  29.250000   157.046980
# 58            NV Ojha  1554  20.720000   114.264706
# 186       Abdul Samad   228  13.411765   139.024390
# 92          STR Binny   880  19.130435   125.714286
# 339          AS Yadav    49   9.800000   122.500000
# 441     Harmeet Singh    18   4.500000   150.000000
# 370         B Sumanth    35  35.000000    92.105263
# 380          AT Carey    32  16.000000   110.344828
# 561  Mashrafe Mortaza     2        NaN   100.000000
# 444          PV Tambe    18   9.000000    46.153846
# 178         JO Holder   247  13.000000   120.487805
# 374          L Ronchi    34   6.800000    91.891892

# %%
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])
for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
x  = [1,2,3,4]
y = [5,6,7,8]
plt.scatter(x,y)
plt.text(1,5,'Point 1')
plt.text(2,6,'Point 2')
plt.text(3,7,'Point 3')
plt.text(4,8,'Point 4')
# Out:
# Text(4, 8, 'Point 4')

# %%
# HORIZONTAL AND VERTICAL LINES

# %%
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])
plt.axhline(130,color='red')
plt.axhline(140,color='green')
plt.axvline(30,color='red')
for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
# a diff way to plot graphs (SUBPLOTS )

# %%
batters.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
fig,axes = plt.subplots(figsize=(15,6))
axes.scatter(batters['avg'],batters['strike_rate'])
axes.set_title("Something")
axes.set_xlabel("Avg")
axes.set_ylabel("Strike rate")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12940\155510256.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig,axes = plt.subplots(2,2,sharex=True)
axes[0,0].scatter(batters['avg'],batters['strike_rate'],color='red')

axes[1,1].scatter(batters['avg'],batters['runs'])
axes[0,1].set_title("Average vs Strike Rate")
axes[1,0].set_ylabel("Strike Rate")

axes[1].set_title("Average vs Runs")
axes[1].set_ylabel("Runs")
axes[1].set_xlabel("Avg")
# Out:
# Text(0.5, 0, 'Avg')
